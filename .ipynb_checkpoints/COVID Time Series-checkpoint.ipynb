# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objs as go

# %%
covid = pd.read_csv('CSVs/covid_19_data_US_Statewise_datetime.csv')

# %%
covid
# Out:
#        SNo ObservationDate Province/State  Country/Region Last Update  \
# 0        1       1/22/2020          Anhui  Mainland China   1/22/2020
# 1        2       1/22/2020        Beijing  Mainland China   1/22/2020
# 2        3       1/22/2020      Chongqing  Mainland China   1/22/2020
# 3        4       1/22/2020         Fujian  Mainland China   1/22/2020
# 4        5       1/22/2020          Gansu  Mainland China   1/22/2020
# ...    ...             ...            ...             ...         ...
# 9730  9731       3/28/2020        Wyoming              US   3/28/2020
# 9731  9732       3/28/2020       Xinjiang  Mainland China   3/28/2020
# 9732  9733       3/28/2020          Yukon          Canada   3/28/2020
# 9733  9734       3/28/2020         Yunnan  Mainland China   3/28/2020
# 9734  9735       3/28/2020       Zhejiang  Mainland China   3/28/2020
#
#       Confirmed  Deaths  Recovered
# 0             1       0          0
# 1            14       0          0
# ...

# %% [markdown]
# # Part A) EDA

# %% [markdown]
# ## 1. Analyze countries like China, South Korea, USA, Italy and Spain individually to see increasing number of cases on day-to-day basis. Provide insight and feedback using a deck as if you were providing findings to Senior management

# %%
countries = ['Mainland China', 'US', 'Italy', 'Spain', 'Korea, South']


five_countries = covid[covid['Country/Region'].isin(countries)]

# %%
grouped = five_countries.groupby(['Country/Region','ObservationDate']).sum()

# %%
grouped.drop(columns=['SNo'], inplace=True)

# %%
# Out:
#                                    SNo  Confirmed  Deaths  Recovered
# Country/Region ObservationDate
# Italy          1/31/2020           481          2       0          0
#                2/1/2020            540          2       0          0
#                2/10/2020          1173          3       0          0
#                2/11/2020          1245          3       0          0
#                2/12/2020          1318          3       0          0
# ...                                ...        ...     ...        ...
# US             3/5/2020         155104        221      12          8
#                3/6/2020         222781        278      14          8
#                3/7/2020         321939        417      17          8
#                3/8/2020         442281        537      21          8
#                3/9/2020         514173        605      22          8
#
# [249 rows x 4 columns]

# %%
for country in countries:
    sns.lineplot(data = grouped, x = 'ObservationDate', y = 'Confirmed', hue ='Country/Region')
    plt.title('Total COVID Cases')
    plt.ylabel('Confirmed Cases')
    plt.xlabel('Date')
    plt.legend(countries)

# %%
for country in countries:
    daily_change = [0]
    for date in range(1 ,len(grouped['ObservationDate'])):
        daily_change.append((grouped[country][date] - grouped[country][date-1]))
    grouped[f'{country}_daily_change'] = daily_change
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ObservationDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-191-f94a4ec1bc82> in <module>
# ...

# %%
change_cols = ['China_daily_change', 'US_daily_change','Italy_daily_change','Spain_daily_change', 'Korea, South_daily_change']

# %%
for country in change_cols:
    sns.lineplot(data=five_countries, x = 'Date', y = country)
    plt.title('Daily Change in Number of COVID Cases')
    plt.ylabel('Change')
    plt.xlabel('Date')
    plt.legend(countries)

# %% [markdown]
# ## 2. Analyze countries together with respect to timelines incorporate measures taken and check for insights. Use web to extract as much information as possible and include conclusions.

# %% [markdown]
# China had the highest number of cases until late March, 2020. The cases in China gradually increased from the beginning of 2020, until they started to plateau in mid-February. Other countries did not start reporting cases until the beginning of March.

# %% [markdown]
# China had large daily increases until mid-February. The US had the highest daily increase in cases from late March onward.

# %% [markdown]
# ## 3. Analyze US States Michigan, New York, Illinois, Ohio and Indiana (Northeastern States only) to identify a trend of deaths and confirmed cases.

# %%
states = ['Michigan', 'Illinois', 'Ohio', 'Indiana', 'New York']

# %%
northeast = cases_us[cases_us['Province_State'].isin(states)]
statewise = northeast.groupby('Province_State').sum()
statewise.drop(columns=['UID', 'code3', 'FIPS', 'Lat', 'Long_'], inplace = True)
statewise = statewise.T.reset_index()

statewise = statewise.rename(columns = {'index': 'Date'})
statewise['Date'] = pd.to_datetime(statewise['Date'], format = '%m/%d/%y')

# %%
northeast_death = deaths_us[deaths_us['Province_State'].isin(states)]
statewise_death = northeast.groupby('Province_State').sum()
statewise_death.drop(columns=['UID', 'code3', 'FIPS', 'Lat', 'Long_'], inplace = True)
statewise_death = statewise_death.T.reset_index()

statewise_death = statewise_death.rename(columns = {'index': 'Date'})
statewise_death['Date'] = pd.to_datetime(statewise_death['Date'], format = '%m/%d/%y')

# %% [markdown]
# #### Confirmed Cases

# %%
plt.subplot(2, 1, 1)
for state in states:
    sns.lineplot(data = statewise, x = 'Date', y = state)
    plt.title('Total COVID Cases')
    plt.ylabel('Confirmed Cases')
    plt.xlabel('Date')
    plt.legend(states)
    
plt.subplot(2, 1, 2)
for state in states:
    sns.lineplot(data = statewise_death, x = 'Date', y = state)
    plt.title('Total COVID Deaths')
    plt.ylabel('Deaths')
    plt.xlabel('Date')
    plt.legend(states)
    
plt.tight_layout()

# %%
no_ny = ['Michigan', 'Illinois', 'Ohio', 'Indiana']

plt.subplot(2, 1, 1)
for state in no_ny:
    sns.lineplot(data = statewise, x = 'Date', y = state)
    plt.title('Total COVID Cases')
    plt.ylabel('Confirmed Cases')
    plt.xlabel('Date')
    plt.legend(no_ny)

plt.subplot(2, 1, 2)
for state in no_ny:
    sns.lineplot(data = statewise_death, x = 'Date', y = state)
    plt.title('Total COVID Deaths')
    plt.ylabel('Deaths')
    plt.xlabel('Date')
    plt.legend(no_ny)
    
plt.tight_layout()

# %% [markdown]
# New York had many more cases than all other states. Cases spiked in late March and only continued to climb. Other states also saw a great increase in cases in late March, but the rate of change was much lower than New York's.

# %% [markdown]
# Looking at the total number of cases without New York gives a more granular picture of the other states. The remaining states had increase in cases similar to each other.

# %%
state_changes = ['Michigan_daily_change', 'Illinois_daily_change', 'Ohio_daily_change', 'Indiana_daily_change', 'New York_daily_change']

# %%
no_ny_change = ['Michigan_daily_change', 'Illinois_daily_change', 'Ohio_daily_change', 'Indiana_daily_change']

# %%
for state in states:
    daily_change = [0]
    for date in range(1 ,len(statewise['Date'])):
        daily_change.append((statewise[state][date] - statewise[state][date-1]))
    statewise[f'{state}_daily_change'] = daily_change

# %%
for state in states:
    daily_change = [0]
    for date in range(1 ,len(statewise_death['Date'])):
        daily_change.append((statewise_death[state][date] - statewise_death[state][date-1]))
    statewise_death[f'{state}_daily_change'] = daily_change

# %%
plt.subplot(2, 1, 1)
for state in state_changes:
    sns.lineplot(data=statewise, x = 'Date', y = state)
    plt.title('Daily Change in Number of COVID Cases')
    plt.ylabel('Change')
    plt.xlabel('Date')
    plt.legend(states, loc='upper left')

plt.subplot(2, 1, 2)    
for change in state_changes:
    sns.lineplot(data=statewise_death, x = 'Date', y = change)
    plt.title('Daily Change in Number of COVID Deaths')
    plt.ylabel('Change')
    plt.xlabel('Date')
    plt.legend(states, loc='upper left')
    
plt.tight_layout()

# %% [markdown]
# New York had an impressive increase of nearly 17,500 cases in one day. New York is also the only state to report a decrease in cases. Whether this decrease is due to recovery or death will be investigated later.

# %%
plt.subplot(2,1,1)
for state in no_ny_change:
    sns.lineplot(data=statewise, x = 'Date', y = state)
    plt.title('Daily Change in Number of COVID Cases')
    plt.ylabel('Change')
    plt.xlabel('Date')
    plt.legend(no_ny)

plt.subplot(2,1,2)    
for change in no_ny_change:
    sns.lineplot(data=statewise_death, x = 'Date', y = change)
    plt.title('Daily Change in Number of COVID Deaths')
    plt.ylabel('Change')
    plt.xlabel('Date')
    plt.legend(no_ny)
    
plt.tight_layout()

# %% [markdown]
# Michigan and Illinois saw greater increases in cases daily than Ohio and Indiana. Though, all four states saw spikes in cases around the same time.

# %% [markdown]
# The trend of deaths nearly perfectly follows the trend of the total number of cases, showing how deadly the disease was.

# %% [markdown]
# ## 4. Use data to identify countries with higher number of cases and perform detailed analysis on:

# %% [markdown]
# ### 1. Age distribution with highest deaths

# %%
df['Country/Region'].value_counts()
# Out:
# Mainland China         2075
# US                     1974
# Australia               372
# Canada                  338
# France                  187
#                        ...
# Cape Verde                1
# Republic of Ireland       1
# East Timor                1
# ('St. Martin',)           1
# North Ireland             1
# Name: Country/Region, Length: 212, dtype: int64

# %% [markdown]
# ### 2. Map different regions over country indicating red dots (use python folium library)

# %% [markdown]
# ### 3. Find number of tests vs confirmed across all the regions/days

# %% [markdown]
# ### 4. Find hospitalized people vs confirmed across all the regions

# %% [markdown]
# ### 5. Find dead people vs recovery across all the regions

# %% [markdown]
# # Part B) Forecasting peak in confirmed cases

# %% [markdown]
# Understand difference between forecasting and predictions. Forecasting needs to be from an API-based calls (You learned this in Thinkful Curriculum).
#
# Try using Facebook’s new API called Prophet which is an adjustable time-series ARIMA forecasting API that can read data and provide a forecast on highest peak for corona screening cases.

# %% [markdown]
# # Part C) Data Storytelling

# %% [markdown]
# Senior Management loves datastories and powerpoint – You heard it right :-)
#
# Create a deck to focus on methods deployed by countries to see the comparison across different countries. Use websites to obtain as much data as possible
#
# Create slide for analysis on US Northeastern States and try to make concluding points on demographics, coronavirus cases and any concluding points
#
# Create a slide on ‘Global Average Expected New Cases Per Day’ using the data from csv files and include expected dates with peaks across these states
#
# Create slide for analysis on timelines across these countries and US Northeastern States and try to make concluding points on demographics, coronavirus cases and any concluding points
